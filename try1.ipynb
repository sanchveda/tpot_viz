# %%
import numpy as np 
import os 
import pdb 
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
plt.rcParams.update({'font.size': 12})

import seaborn as sns 

class_dict = {0: 'Aggressive' , 1:'Dysphoric' , 2:'Positive', 3:'other'}
root_dir = '/run/user/1435515045/gvfs/smb-share:server=terracotta.psychology.pitt.edu,share=projects/Sanchayan/tpot_data/'
folds=sorted([name for name in os.listdir(root_dir) if name.startswith('train')])

def load_text_data():
    data = np.load ('text_data1.npy',allow_pickle=True).item()

    family= data ['family'] 
    start_time=data ['start_time']
    end_time=data ['end_time'] 
    duration=data ['duration'] 
    subject=data ['subject'] 
    text=data ['text'] 

    return [family, start_time, end_time, duration, subject, text]


def turn_per_construct(t_start,t_end, c_start,c_end, t_speaker, c_speaker, t_duration):


    arr1= np.zeros_like(c_start) #------Number of overlaps + inside per construct 

    arr2= np.zeros_like(c_start) #--------Number of turns strictly in the window --

    arr3= np.zeros_like(c_start) #------Number of tutrns that wraps the construct

    arr4= np.zeros_like(c_start) #---------Number of turns whose majority fall in the construct interval
    for idx , (start_c, end_c, speaker_c) in enumerate(zip(c_start,c_end,c_speaker)):

        for jj, (start_t , end_t , speaker_t, duration ) in enumerate(zip(t_start, t_end, t_speaker, t_duration)):


            if speaker_c == speaker_t :
                # Case 1: All turns which fall in the construct interva even if it is partial +plus those that wrap
                if (start_t< start_c and end_t > start_c and end_c > end_t)\
                    or (start_t < end_c and end_t > end_c and start_c < start_t) \
                    or (start_t >= start_c and end_t <= end_c)\
                    or (start_t < start_c and end_t > end_c) :
                        arr1[idx] = arr1[idx] +1 


                # Case 2: Only those turns that is strictly between construct interval
                if start_t >= start_c and end_t <= end_c:
                    arr2[idx] = arr2[idx] +1


                # Case 3 : Only those turns  which cover the entire construct intterval + plus extra
                if (start_t < start_c and end_t > end_c):
                    arr3[idx]= arr3[idx] + 1


                #Case 4 : If the majority of turn falls in the constuct interval
                if ((end_t > start_c and start_t < start_c and end_c> end_t) and  (end_t - start_c > duration/2) ) \
                    or ((start_t < end_c and end_t > end_c and start_c < start_t) and (end_c-start_t > duration/2)) \
                    or (start_t >= start_c and end_t <= end_c) \
                    or ((start_t < start_c and end_t> end_c )and (end_c - start_c > duration/2)) :
                        arr4[idx] = arr4[idx] + 1


    return  arr1,arr2,arr3,arr4

def new_turn_per_construct(t_start,t_end, c_start,c_end, t_speaker, c_speaker, t_duration):


    arr1= np.zeros_like(c_start) #------Number of overlaps + inside per construct 

    arr2= np.zeros_like(c_start) #--------Number of turns strictly in the window --

    arr3= np.zeros_like(c_start) #------Number of tutrns that wraps the construct

    arr4= np.zeros_like(c_start) #---------Number of turns whose majority fall in the construct interval


    neg1 = np.zeros_like(c_start)
    neg2 = np.zeros_like(c_start)
    for idx , (start_c, end_c, speaker_c) in enumerate(zip(c_start,c_end,c_speaker)):

        for jj, (start_t , end_t , speaker_t, duration ) in enumerate(zip(t_start, t_end, t_speaker, t_duration)):

            if speaker_c == speaker_t :
                # Case 1: All turns which fall in the construct interva even if it is partial +plus those that wrap
                if (start_t< start_c and end_t > start_c and end_c > end_t)\
                    or (start_t < end_c and end_t > end_c and start_c < start_t) \
                    or (start_t >= start_c and end_t <= end_c)\
                    or (start_t < start_c and end_t > end_c) :
                        arr1[idx] = arr1[idx] +1 


                # Case 2: Only those turns that is strictly between construct interval
                if start_t >= start_c and end_t <= end_c:
                    arr2[idx] = arr2[idx] +1


                # Case 3 : Only those turns  which cover the entire construct intterval + plus extra
                if (start_t < start_c and end_t > end_c):
                    arr3[idx]= arr3[idx] + 1


                #Case 4 : If the majority of turn falls in the constuct interval
                if ((end_t > start_c and start_t < start_c and end_c> end_t) and  (end_t - start_c > duration/2) ) \
                    or ((start_t < end_c and end_t > end_c and start_c < start_t) and (end_c-start_t > duration/2)) \
                    or (start_t >= start_c and end_t <= end_c) \
                    or ((start_t < start_c and end_t> end_c )and (end_c - start_c > duration/2)) :
                        arr4[idx] = arr4[idx] + 1



            elif speaker_c != speaker_t :
                if (start_t< start_c and end_t > start_c and end_c > end_t)\
                    or (start_t < end_c and end_t > end_c and start_c < start_t) \
                    or (start_t >= start_c and end_t <=  end_c)\
                    or (start_t < start_c and end_t > end_c) :
                        neg1[idx] = neg1[idx] + 1

                if ((end_t > start_c and start_t < start_c and end_c> end_t) and  (end_t - start_c > duration/2) ) \
                    or ((start_t < end_c and end_t > end_c and start_c < start_t) and (end_c-start_t > duration/2)) \
                    or (start_t >= start_c and end_t <= end_c) \
                    or ((start_t < start_c and end_t> end_c )and (end_c - start_c > duration/2)) :
                        neg2[idx] = neg2[idx] + 1


    return  arr1,arr2,arr3,arr4, neg1, neg2


def get_proportion(t_start,t_end, c_start,c_end, t_speaker, c_speaker, t_duration, c_duration):


    arr1= np.zeros_like(c_start) #------Number of overlaps + inside per construct 

    arr2= np.zeros_like(c_start) #--------Number of turns strictly in the window --

    arr3= np.zeros_like(c_start) #------Number of tutrns that wraps the construct




    neg1 = np.zeros_like(c_start)
    neg2 = np.zeros_like(c_start)
    for idx , (start_c, end_c, speaker_c) in enumerate(zip(c_start,c_end,c_speaker)):
        for jj, (start_t , end_t , speaker_t, duration ) in enumerate(zip(t_start, t_end, t_speaker, t_duration)):

            if speaker_c == speaker_t :
                # Case 1: All turns which fall in the construct interva even if it is partial +plus those that wrap
                if (start_t< start_c and end_t > start_c and end_c > end_t) : 
                    arr1[idx]  +=  end_t - start_c 

                elif (start_t < end_c and end_t > end_c and start_c < start_t):
                    arr1[idx] +=  end_c - start_t 

                elif (start_t >= start_c and end_t <= end_c) :
                    arr1[idx] += end_t - start_t 

                elif (start_t < start_c and end_t > end_c) :
                    arr1[idx] += end_c- start_c 






            elif speaker_c != speaker_t :
                if (start_t< start_c and end_t > start_c and end_c > end_t) : 
                    arr2[idx]  +=  end_t - start_c 

                elif (start_t < end_c and end_t > end_c and start_c < start_t):
                    arr2[idx] +=  end_c - start_t 

                elif (start_t >= start_c and end_t <= end_c) :
                    arr2[idx] += end_t - start_t 

                elif (start_t < start_c and end_t > end_c) :
                    arr2[idx] += end_c - start_c 



    arr3 = c_duration - ( arr1 +  arr2 )

    arr4 = arr1 / c_duration
    arr5 = arr2 / c_duration


    indices = ~np.isnan(arr4)  & ~np.isnan(arr5)

    arr1= arr1[indices]
    arr2= arr2[indices]
    arr3= arr3[indices]
    arr4= arr4[indices]
    arr5= arr5[indices]


    return  arr1,arr2,arr3 , arr4, arr5 , indices



def get_overlap (start_t, end_t, start_c, end_c, speaker_t, speaker_c, duration_t, duration_c, mode='case2'):
    duration = 0


    if mode == 'case2':
        if start_c < start_t and end_c > start_t and end_t> end_c:
            duration = end_c - start_t 
        elif start_c<end_t and end_c > end_t and start_t < start_c:
            duration = end_t - start_c
        elif start_c >= start_t and end_c <= end_t:
            duration = end_c - start_c 
        elif start_c < start_t and end_c> end_t:
            duration = end_t - start_t 

    return duration

def get_majority_construct (t_start,t_end, c_start,c_end, t_speaker, c_speaker, t_duration,c_duration, label):

    arr2= np.zeros_like(t_start)
    label2= np.full(arr2.shape, -1)


    majority = np.zeros_like(t_start)
    for idx, (start_t , end_t , speaker_t, duration ) in enumerate(zip(t_start, t_end, t_speaker, t_duration)):

        for jj , (start_c, end_c, speaker_c, duration_c, construct) in enumerate(zip(c_start,c_end,c_speaker, c_duration, label)):

            if speaker_c== speaker_t:

                d = get_overlap (start_t, end_t , start_c , end_c , speaker_t, speaker_c, duration, duration_c)

                if d > arr2[idx]:
                    arr2[idx] = d 
                    label2[idx] = construct

    return arr2, label2


def get_all_utterance (t_start, t_end, c_start, c_end, t_speaker, c_speaker, t_duration, c_duration, t_text):
    arr1= np.zeros_like(c_start)
    arr= []

    mark= np.full(arr1.shape, -1)

    for idx , (start_c, end_c, speaker_c) in enumerate(zip(c_start,c_end,c_speaker)):

        utterance = ""
        for jj, (start_t , end_t , speaker_t, duration , text) in enumerate(zip(t_start, t_end, t_speaker, t_duration, t_text)):
            if speaker_c == speaker_t :
                # Case 1: All turns which fall in the construct interva even if it is partial +plus those that wrap
                if (start_t< start_c and end_t > start_c and end_c > end_t)\
                    or (start_t < end_c and end_t > end_c and start_c < start_t) \
                    or (start_t >= start_c and end_t <= end_c)\
                    or (start_t < start_c and end_t > end_c) :
                        arr1[idx] = arr1[idx] +1 
                        try:
                            utterance += text + " "	
                        except:
                            pdb.set_trace()



        #arr= np.vstack [arr, utterance] if arr is not None else utterance
        if utterance != "":
            mark[idx]=len(utterance)
        arr.append(utterance.rstrip())
    arr= np.array(arr)

    return mark, arr  



def plot_histogram (x_label, y_label, title, name,   data):

    #bins = np.arange(0,np.max(arr)+1)
    #bins = np.arange(0,np.max(data)+1).astype(int)
    #bins = np.linspace (0, np.max(data) + 1, np.max(data) + 1)
    x= np.arange( 0, np.max(data)+1).astype(int)

    y= np.zeros_like(x).astype('float')
    for idx in x:
        y[idx]=np.sum (data == idx) / len(data)

    #bins = len(np.unique(data))
    #plt.hist(data, bins=bins)
    plt.bar (x=x, height=y, tick_label=list(x))
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.ylim(0.0,0.6)
    #plt.gcf().text(0.9, 0.1, "Totat="+str(len(data)), fontsize=10)
    plt.title(title)
    plt.savefig (name+'.jpg')
    plt.close()
    return 


def plot_percentage1 (x_label, y_label, title, name,   data):

    #bins = np.arange(0,np.max(arr)+1)
    #bins = np.arange(0,np.max(data)+1).astype(int)
    #bins = np.linspace (0, np.max(data) + 1, np.max(data) + 1)
    x= np.arange( 0, np.max(data)+1).astype(int)

    y= np.zeros_like(x)
    for idx in x:
        y[idx]=np.sum (data == idx)


    #pdb.set_trace()
    #ax= sns.violinplot (x=, y=y_label, data= data )

    #bins = len(np.unique(data))
    plt.hist(data, bins=5)
    #plt.bar (x=x, height=y, tick_label=list(x))
    #plt.xlabel(x_label)
    #plt.ylabel(y_label)
    #plt.gcf().text(0.9, 0.1, "Totat="+str(len(data)), fontsize=10)
    plt.title(title)
    plt.savefig (name+'.jpg')
    plt.close()
    return 

def plot_percentage (x_label, y_label, title, name,   data):

    y , x = data	

    ax= sns.violinplot (x=x, y=y)

    #bins = len(np.unique(data))
    #plt.hist(data, bins=5)
    #plt.bar (x=x, height=y, tick_label=list(x))
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    #plt.gcf().text(0.9, 0.1, "Totat="+str(len(data)), fontsize=10)
    plt.title(title)
    plt.savefig (name+'.jpg')
    plt.close()
    return 

def differential_analysis(x1_list, construct_list, title=None, case='case_1'):

    elements = []


    for i in np.unique (construct_list):

        #elements = x1_list [x1_list == 0]

        indices = (construct_list == i)
        new_list = x1_list [indices]


        if title is None :
            plot_histogram(y_label='Number of constructs (Total='+str(len(new_list))+')', x_label='Speaker-Turns/construct', title='Histogram for number of Speaker-Turns for ' + class_dict[int(i)], name='utterance_'+case + class_dict[int(i)], data=new_list)
        else:
            plot_histogram(y_label='Number of constructs (Total='+str(len(new_list))+')', x_label='Speaker-Turns/construct', title=title +' for '+ class_dict[int(i)], name='utterance_'+case + class_dict[int(i)], data=new_list)

        #elements.append(sum(indices))
    #pdb.set_trace()
    return elements

def subject_analysis (x1_list,construct_list, subject_list,version='same', case='case_1'):


    d = {'1': 'Child', '2': 'Mother'}

    for jj in np.unique (construct_list):

        indexes= construct_list == jj 
        x_list =  x1_list[indexes]
        sub_list= subject_list[indexes]

        for i in np.unique (subject_list):


            indices = sub_list == i
            new_list = x_list [indices]

            if version == 'same':
                plot_histogram (y_label='Number of constructs (Total='+str(len(new_list))+')', x_label='Speaker-Turns/construct', title='Histogram for number of Speaker-Turns for ' + d[i] +'_'+class_dict[int(jj)], name='utterance_'+ case + d[i] + class_dict[int(jj)], data=new_list)
            else:
                plot_histogram (y_label='Number of constructs (Total='+str(len(new_list))+')', x_label='Speaker-Turns/construct', title='Histogram for number of Other Speaker turns for ' + d[i] +'_'+ class_dict[int(jj)], name='utterance_'+ case + d[i]+ class_dict[int(jj)], data=new_list)

    return 

def subject_percentage1 (x1_list,construct_list, subject_list,version='same', case='case_1'):


    d = {'1': 'Child', '2': 'Mother'}

    for jj in np.unique (construct_list):

        indexes= construct_list == jj 
        x_list =  x1_list[indexes]
        sub_list= subject_list[indexes]

        for i in np.unique (subject_list):


            indices = sub_list == i
            new_list = x_list [indices]

            if version == 'same':
                plot_percentage (y_label='Number of constructs (Total='+str(len(new_list))+')', x_label='Proportion of Turn time/construct', title='Histogram for number of Speaker Time  for ' + d[i] +'_'+class_dict[int(jj)], name='utterance_'+ case + d[i] + class_dict[int(jj)], data=new_list)
            else:
                plot_percentage (y_label='Number of constructs (Total='+str(len(new_list))+')', x_label='Proportion of Turn time/construct', title='Histogram for number of Other Speaker Time for ' + d[i] +'_'+ class_dict[int(jj)], name='utterance_'+ case + d[i]+ class_dict[int(jj)], data=new_list)

    return 


def violin_plot (x1_list,construct_list, subject_list,version='same', case='case_1'):


    d = {'1': 'Child', '2': 'Mother'}


    for i in np.unique (subject_list):


            indices = subject_list == i
            new_list = x1_list [indices]
            new_construct_list= construct_list[indices]

            sorted_indices = np.argsort(new_construct_list)
            new_list = new_list [sorted_indices]
            new_construct_list= new_construct_list[sorted_indices]
            love_list = np.array([class_dict[int(j)] for j in new_construct_list])
            print (min(new_list))
            if version == 'same':
                plot_percentage (y_label='Proportion of Turn Time / Construct', x_label='Constructs', title='Violin Plot of Same Speaker in '+ d[i]+' constructs', name='utterance_'+ case + d[i] , data=[new_list, love_list])
            else:
                plot_percentage (y_label='Proportion of Turn Time / Construct', x_label='Constructs', title='Violin Plot of Other Speaker in' + d[i]+' constructs' , name='utterance_'+ case + d[i], data=[new_list,love_list])

    return 


def construct_per_turn (t_start,t_end, c_start,c_end, t_speaker, c_speaker, t_duration,c_duration, label=None, text=None):
    arr1= np.zeros_like(t_start)

    arr2= np.zeros_like(t_start)

    arr3= np.zeros_like(t_start)

    annot_arr1 = []
    annot_arr2 = []
    annot_arr3 = []

    annot_neg_arr1=[]
    annot_neg_arr2=[]

    neg_arr1= np.zeros_like(t_start)
    neg_arr2= np.zeros_like(t_start)
    neg_arr3= np.zeros_like(t_start)


    #---Onsets----
    onset_arr2=[]


    for idx, (start_t , end_t , speaker_t, duration , turn) in enumerate(zip(t_start, t_end, t_speaker, t_duration, text)):

        temp_arr1 =[]
        temp_arr2 =[]
        temp_arr3 =[]

        temp_neg_arr1=[]
        temp_neg_arr2=[]

        temp_onset_1=[]
        temp_onset_2=[]



        for jj , (start_c, end_c, speaker_c, duration_c, lab) in enumerate(zip(c_start,c_end,c_speaker, c_duration, label)):




            "Conditions for same person behavior constructs in current turn  "
            if speaker_t == speaker_c:

                #Case 1: If tthe onset falls anwhhere within the turn
                if start_c >= start_t  and start_c < end_t:
                    arr1[idx] = arr1[idx] +1 
                    temp_arr1.append (int(lab))
                    temp_onset_1.append( [start_c,end_c] )



                #Case 2: Where all constructs in the speaker turn are considered as labels 
                if (start_c < start_t  and  end_c > start_t and end_t> end_c) or (start_c < end_t  and end_c > end_t and start_t <start_c) or (start_c >= start_t and end_c <= end_t) or (start_c < start_t and end_c>end_t):
                    arr2[idx] = arr2[idx] +1 
                    temp_arr2.append(int(lab))
                    temp_onset_2.append([start_c,end_c])


                #Case 3: Only majority of construct
                if ((start_c < start_t  and  end_c > start_t and end_t> end_c)  and (end_c - start_t > duration_c /2) ) \
                    or ((start_c < end_t and end_c > end_t and start_t < start_c) and (end_t - start_c > duration_c/2)) \
                    or (start_c >= start_t and end_c <= end_t) \
                    or ((start_c < start_t and end_c>end_t) and (end_t - start_t > duration_c/2)):
                        arr3[idx]= arr3[idx] +1
                        temp_arr3.append(int(lab)) 


            #" The below conditions are for other person's behavior constructs in current turn"	
            elif speaker_t != speaker_c:
                if start_c >= start_t  and start_c < end_t:
                    #arr1[idx]= arr1[idx]+1 
                    neg_arr1[idx] = neg_arr1[idx] +1 
                    temp_neg_arr1.append(int(lab))

                #Case 2: Where all constructs in the speaker turn are considered as labels 
                if (start_c < start_t  and  end_c > start_t and end_t> end_c) or\
                   (start_c < end_t  and end_c > end_t and start_t <start_c) or \
                   (start_c >= start_t and end_c <= end_t) or \
                   (start_c < start_t and end_c>end_t):
                    #arr2[idx]= arr2[idx]+1 
                    neg_arr2[idx] = neg_arr2[idx] +1
                    temp_neg_arr2.append(int(lab)) 


                #Case 3: Only majority of construct
                if ((start_c < start_t  and  end_c > start_t and end_t> end_c)  and (end_c - start_t > duration_c /2) ) \
                    or ((start_c < end_t and end_c > end_t and start_t < start_c) and (end_t - start_c > duration_c/2)) \
                    or (start_c >= start_t and end_c <= end_t) \
                    or ((start_c < start_t and end_c>end_t) and (end_t - start_t > duration_c/2)):
                        neg_arr3[idx]= neg_arr3[idx] +1 

        #print (turn, speaker_t, start_t , end_t , temp_arr2, temp_onset_2)

        #pdb.set_trace()
        annot_arr1.append (np.array(temp_arr1).astype('int'))
        annot_arr2.append (np.array(temp_arr2).astype('int'))
        annot_arr3.append (np.array(temp_arr3).astype('int'))

        annot_neg_arr1.append(np.array(temp_neg_arr1).astype('int'))
        annot_neg_arr2.append(np.array(temp_neg_arr2).astype('int'))


        onset_arr2.append (np.array(temp_onset_2).astype('float'))




    return arr1, arr2, arr3, neg_arr1, neg_arr2, [annot_arr2, annot_neg_arr2], [onset_arr2]

def turn_pauses_overlaps (t_start,t_end, c_start,c_end, t_speaker, c_speaker, t_duration,c_duration, label=None, text=None):

    overlap_count = np.zeros_like(t_start)
    overlap_duration= np.zeros_like(t_start).astype('float')

    pause_duration = np.zeros_like (t_start).astype('float')

    within_duration = np.zeros_like (t_start).astype('float')
    between_duration= np.zeros_like (t_start).astype('float')

    prev_end = 0
    prev_speaker= None


    for idx, (start_t , end_t , speaker_t, duration , turn) in enumerate(zip(t_start, t_end, t_speaker, t_duration, text)):


        # for overlaps
        if start_t < prev_end and idx > 0:
            overlap_count [idx] += 1
            overlap_duration[idx] = prev_end - start_t

        # for pauses
        if start_t > prev_end and idx > 0:
            pause_duration[idx] = start_t - prev_end


        # For within speaker pauses 
        if start_t > prev_end and speaker_t == prev_speaker and idx > 0:
            within_duration[idx] = start_t - prev_end

        # For between speaker pauses
        if start_t > prev_end and speaker_t != prev_speaker and idx > 0:
            between_duration[idx]= start_t - prev_end


        prev_end = end_t 
        prev_speaker= speaker_t



    return [overlap_count, overlap_duration], [pause_duration, within_duration, between_duration]

def turn_statistics (data_lists):

    turn_duration, overlap_count, overlap_duration, pause_duration, within_duration, between_duration, speaker= data_lists


    total_turns = speaker.size
    parent_turns = np.sum (speaker =='2')
    child_turns = np.sum (speaker =='1')

    child_duration = turn_duration[ speaker=='1']
    parent_duration = turn_duration [ speaker =='2']

    total_overlap = np.sum (overlap_count) 
    parent_overlap = np.sum(overlap_count [speaker == '2']) 
    child_overlap = np.sum (overlap_count [speaker == '1']) 


    total_ov_duration=  overlap_duration[overlap_count==1]
    child_ov_duration = overlap_duration [(speaker == '1') & (overlap_count==1)]
    parent_ov_duration= overlap_duration [(speaker == '2') & (overlap_count==1)]


    total_pause_duration = pause_duration [overlap_count==0]
    child_pause_duration = pause_duration [(speaker=='1') & (overlap_count==0)]
    parent_pause_duration = pause_duration [(speaker=='2') & (overlap_count==0)]


    total_within_duration = within_duration[within_duration > 0]
    child_within_duration = within_duration [ (speaker=='1') & (within_duration>0)]
    parent_within_duration= within_duration [ (speaker=='2') & (within_duration>0)]


    total_between_duration = between_duration[between_duration> 0]
    child_between_duration = between_duration [ (speaker=='1') & (between_duration>0)]
    parent_between_duration= between_duration [ (speaker=='2') & (between_duration>0)]


    print ("Total turns=", total_turns, "parent_turns=", parent_turns, float(parent_turns)/total_turns ,"child_turns=", child_turns, float(child_turns)/total_turns)


    print ("Total Overlap=", total_overlap, "parent_overlap=", parent_overlap, float(parent_overlap)/child_overlap, "child_overlap=", child_overlap,float(child_overlap)/total_overlap)

    print ("Turn duration=",np.mean (turn_duration), np.std (turn_duration))
    print ("child_duration=", np.mean(child_duration), np.std (child_duration))
    print ("parent_duration=", np.mean(parent_duration), np.std(parent_duration))


    print ("Mean overlap duration", np.mean(total_ov_duration), "Standard Deviation", np.std(total_ov_duration))
    print ("Child Overlap Duration", np.mean(child_ov_duration), np.std(child_ov_duration))
    print ("Parent Overlap Duration", np.mean(parent_ov_duration), np.std(parent_ov_duration))


    print ("Mean pause duration", np.mean(total_pause_duration), np.std(total_pause_duration), len(total_pause_duration))
    print ("Child pause_duration", np.mean(child_pause_duration), np.std(child_pause_duration), len(child_pause_duration))
    print ("Mother pause_duration", np.mean(parent_pause_duration), np.std(parent_pause_duration), len(parent_pause_duration))


    print ("Mean within duration", np.mean(total_within_duration) , np.std (total_within_duration), len(total_within_duration))
    print ("Child within duration", np.mean(child_within_duration), np.std (child_within_duration), len(child_within_duration))
    print ("Parentt within duration", np.mean(parent_within_duration), np.std(parent_within_duration), len(parent_within_duration))

    print ("Mean between durationn", np.mean(total_between_duration), np.std (total_between_duration), len(total_between_duration))
    print ("Child between duration", np.mean(child_between_duration), np.std (child_between_duration), len(child_between_duration))
    print ("Parent between_duration", np.mean(parent_between_duration), np.std (parent_between_duration), len(parent_between_duration))

    pdb.set_trace()
    return


def plot_turns (x_list, subject_list, version='same', case='case1'):
    def plot_histogram (x_label, y_label, title, name,   data):
        #bins = np.arange(0,np.max(arr)+1)
        #bins = np.arange(0,np.max(data)+1).astype(int)
        #bins = np.linspace (0, np.max(data) + 1, np.max(data) + 1)
        x= np.arange( 0, np.max(data)+1).astype(int)

        y= np.zeros_like(x).astype('float')
        for idx in x:
            y[idx]=np.sum (data == idx)  / len(data)


        #bins = len(np.unique(data))
        #plt.hist(data, bins=bins)
        plt.bar (x=x, height=y, tick_label=list(x))
        plt.xlabel(x_label)
        plt.ylabel(y_label)
        plt.ylim(0.0,1.0)

        #plt.gcf().text(0.9, 0.1, "Totat="+str(len(data)), fontsize=10)
        plt.title(title)
        plt.savefig (name+'.jpg')
        plt.close()
        return 


    dict_speaker = {'1': 'Child', '2': 'Mother'}

    #------------General---------------------#
    if version == 'same':
        plot_histogram ("Number OF Construct/ Turn", " Number of Turns (Proportion) ", title="Histogram of Number of  all speaker constructs", name='turn_'+version +'_'+case, data=x_list )
    else:
        plot_histogram ("Number OF Construct/ Turn", " Number of Turns (Proportion) ", title="Histogram of Number of Other speaker constructs", name='turn_'+version +'_'+case, data=x_list )


    #-------Differential---------------#
    for i in np.unique(subject_list):

        sub_indices = subject_list == i 
        sub_list   = x_list [ sub_indices]


        if version == 'same':

            plot_histogram ("Number OF Construct/ Turn", " Number of Turns (Proportion) ", title="Histogram of Number of all speaker  constructs for "+dict_speaker[i], name='turn_'+version + '_'+ dict_speaker[i] + '_'+case, data=sub_list )
        else:
            plot_histogram ("Number OF Construct/ Turn", " Number of Turns (Proportion) ", title="Histogram of Number of Other speaker constructs for "+dict_speaker[i], name='turn_'+version + '_'+ dict_speaker[i] +'_'+ case, data=sub_list )

    return 


def plot_turn_length (x_list, subject_list, case='case1'):
    def plot_histogram (x_label, y_label, title, name,   data):
        #bins = np.arange(0,np.max(arr)+1)
        #bins = np.arange(0,np.max(data)+1).astype(int)
        #bins = np.linspace (0, np.max(data) + 1, np.max(data) + 1)
        x= np.arange( 0, np.max(data)+1).astype(int)

        y= np.zeros_like(x).astype('float')
        for idx in x:
            y[idx]=np.sum (data == idx)  / len(data)

        "Ffor perceentage"
        weights=np.ones(len(data)) / len(data)	
        #bins = len(np.unique(data))
        #plt.hist(data, bins=bins)
        #plt.bar (x=x, height=y, tick_label=list(x))
        plt.hist(data, weights= weights,bins=10)
        plt.xlabel(x_label)
        plt.ylabel(y_label)
        plt.gca().yaxis.set_major_formatter(PercentFormatter(xmax=1.0,decimals=0))
        #plt.gcf().text(0.9, 0.1, "Totat="+str(len(data)), fontsize=10)

        plt.title(title)
        plt.savefig (name+'.jpg')
        plt.close()
        return 


    dict_speaker = {'1': 'Child', '2': 'Mother'}


    #-------Differential---------------#
    for i in np.unique(subject_list):

        sub_indices = subject_list == i 
        sub_list   = x_list [ sub_indices]


        plot_histogram ("Turn duration (in sec)",  " Number of Turns (in percentage)", title="Distribution of "+dict_speaker[i]+" turn duration time", name='duration_'+ dict_speaker[i] + '_'+case, data=sub_list )

    plot_histogram ("Turn duration (in sec)", "Number of Turns (in percentage) ", title="Distribution of turn duration", name='duration_'+case, data=x_list )

    return 

def length_analysis (x1_list,construct_list, duration_list,  subject_list,version='same', case='case_1'):

    def plot_length (x_label, y_label, title, name,   data):

        y , x = data	


        plt.bar (x=x, height=y)
        #bins = len(np.unique(data))
        #plt.hist(data, bins=5)
        #plt.bar (x=x, height=y, tick_label=list(x))
        plt.xlabel(x_label)
        plt.ylabel(y_label)
        #plt.gcf().text(0.9, 0.1, "Totat="+str(len(data)), fontsize=10)
        plt.title(title)
        plt.savefig (name+'.jpg')
        plt.close()
        return 


    d = {'1': 'Child', '2': 'Mother'}


    for i in np.unique (subject_list):


            indices = subject_list == i
            new_list = x1_list [indices]
            new_construct_list= construct_list[indices]
            new_duration_list = duration_list[indices]

            sorted_indices = np.argsort(new_duration_list)
            new_list = new_list [sorted_indices] + 1
            new_construct_list= new_construct_list[sorted_indices]
            new_duration_list= new_duration_list[sorted_indices]
            #love_list = np.array([class_dict[int(j)] for j in new_construct_list])
            print (max(new_duration_list))
            if version == 'same':
                plot_length (y_label='Number of Speaker-Turns', x_label='Construct duration (in sec)', title='Turn count  of Same Speaker in '+ d[i]+' constructs', name='utterance_'+ case + d[i] , data=[new_list, new_duration_list])
            else:
                plot_length (y_label='Number of Speaker-Turns', x_label='Construct duration (in sec)', title='Turn count  of Other Speaker in' + d[i]+' constructs' , name='utterance_'+ case + d[i], data=[new_list,new_duration_list])

    return 





def analyze(res):
    [family, start_time, end_time, duration, subject, text]= load_text_data()

    pdb.set_trace()

    audio=res['audio']
    video=res['video']
    label=res['label']
    speaker=res['speaker']
    time=res['time']
    frame=res['frame']
    filename=res['filenames']


    x1_list=[]
    x2_list=[]
    x3_list=[]
    x4_list=[]
    x5_list=[]
    construct_list=[]
    speaker_list = []

    neg1_list=[]
    neg2_list=[]

    y1_list=[]
    y2_list=[]
    y3_list=[]
    ny1_list=[]
    ny2_list=[]
    speakert_list=[]
    turn_start_list=[]
    turn_end_list=[]
    turn_text_list=[]
    turn_duration_list=[]
    turn_label_list=[]
    turn_onset_list=[]




    #----------Declarattion for analysyis of gaps and pauses

    overlap_count_list = []
    overlap_duration_list=[]
    pause_duration_list=[]
    within_duration_list=[]
    between_duration_list=[]
    #--------------------



    onset = [x[0] for x in time]
    offset = [x[1] for x in time]

    start_frame =[x[0] for x in frame]
    end_frame = [x[1] for x in frame]

    file_list = [x[0] for x in filename]
    file_list = [x.split('_')[0][:-1][-4:] for x in file_list]

    dur_c=[] 
    dur_t=[]
    for idx, fam in enumerate(family):

        check_fam =np.array( [x.find(fam) for x in file_list]) 	
        check_fam = np.where(check_fam>-1)[0]

        if len (check_fam) > 0:
            idx_fam = check_fam[0]

            value_1= onset [idx_fam]
            value_2= offset[idx_fam]


            #x1,x2,x3,x4 = turn_per_construct (start_time[idx], end_time[idx], onset[check_fam[0]], offset[check_fam[0]], subject[idx], speaker[check_fam[0]], duration[idx])
            y1,y2,y3, ny1, ny2, [pos_annot, neg_annot], [onset_info]= construct_per_turn (start_time[idx], end_time[idx], onset[check_fam[0]], offset[check_fam[0]], subject[idx], speaker[check_fam[0]], duration[idx], value_2-value_1,
                                label= label[idx_fam],\
                                text= text[idx])

            [overlap_count,overlap_duration],[pause_duration, within_duration, between_duration]= turn_pauses_overlaps (start_time[idx], end_time[idx], onset[check_fam[0]], offset[check_fam[0]], subject[idx], speaker[check_fam[0]], duration[idx], value_2-value_1,
                                label= label[idx_fam],\
                                text= text[idx])


            x1,x2,x3,x4 ,neg1,neg2= new_turn_per_construct (start_time[idx], end_time[idx], onset[check_fam[0]], offset[check_fam[0]], subject[idx], speaker[check_fam[0]], duration[idx])

            #----------This gets majority constructs label per turns ------------#
            new_duration,new_label= get_majority_construct (start_time[idx], end_time[idx], onset[check_fam[0]], offset[check_fam[0]], subject[idx], speaker[check_fam[0]], duration[idx], value_2-value_1, label[check_fam[0]])


            _, _, _, _, x5 , indices= get_proportion (start_time[idx], end_time[idx], onset[check_fam[0]], offset[check_fam[0]], subject[idx], speaker[check_fam[0]], duration[idx], value_2-value_1)

            dur_c.extend ((value_2-value_1)[indices])
            dur_t.extend (duration[idx])
            #new_mark, new_utterance=  get_all_utterance (start_time[idx], end_time[idx], onset[check_fam[0]], offset[check_fam[0]], subject[idx], speaker[check_fam[0]], duration[idx], value_2-value_1, text[idx])

            x1_list.append(x1[indices])
            x2_list.append(x2[indices])
            x3_list.append(x3[indices])
            x4_list.append(x4[indices])
            x5_list.append(x5)
            construct_list.append(label[check_fam[0]][indices])

            speaker_list.append (speaker[check_fam[0]][indices])
            neg1_list.append(neg1[indices])
            neg2_list.append(neg2)


            "Speaker information . Preparing for turns"
            y1_list.append(y1)
            y2_list.append(y2)
            y3_list.append(y3)
            ny1_list.append(ny1)
            ny2_list.append(ny2)

            speakert_list.append(subject[idx])
            turn_duration_list.append (duration[idx])
            turn_start_list.append( start_time[idx])
            turn_end_list.append( end_time[idx])
            turn_text_list.append( text[idx])
            turn_label_list.append ( pos_annot )
            turn_onset_list.append (onset_info)


            "Turn analsis"
            overlap_count_list.append(overlap_count)
            overlap_duration_list.append(overlap_duration)
            pause_duration_list.append(pause_duration)
            within_duration_list.append(within_duration)
            between_duration_list.append(between_duration)




    x1_list=np.concatenate(np.array(x1_list))
    x2_list=np.concatenate(np.array(x2_list))
    x3_list=np.concatenate(np.array(x3_list))
    x4_list=np.concatenate(np.array(x4_list))
    x5_list=np.concatenate(np.array(x5_list))

    construct_list= np.concatenate(np.array(construct_list))
    speaker_list= np.concatenate(np.array(speaker_list))

    y1_list= np.concatenate(np.array(y1_list))
    y2_list= np.concatenate(np.array(y2_list))
    y3_list= np.concatenate(np.array(y3_list))
    ny1_list= np.concatenate(np.array(ny1_list))
    ny2_list= np.concatenate(np.array(ny2_list))
    turn_speaker_list=np.concatenate(np.array(speakert_list))

    pdb.set_trace()
    '''
    "Analyzing turn statistics"
    overlap_count_list= np.concatenate(np.array(overlap_count_list))
    overlap_duration_list= np.concatenate(np.array(overlap_duration_list))
    pause_duration_list= np.concatenate(np.array(pause_duration_list))
    within_duration_list=np.concatenate(np.array(within_duration_list))
    between_duration_list=np.concatenate(np.array(between_duration_list))
    turn_duration_list= np.concatenate (np.array(turn_duration_list))

    turn_statistics ( [turn_duration_list,overlap_count_list, overlap_duration_list, pause_duration_list, within_duration_list, between_duration_list, turn_speaker_list] )
    dur_c = np.array (dur_c)

    neg1_list=	np.concatenate( np.array(neg1_list) )
    neg2_list= 	np.concatenate( np.array(neg2_list) )
    '''

    #length_analysis (x1_list, construct_list, dur_c, speaker_list, version='same', case='case_1')
    #length_analysis (neg1_list, construct_list, dur_c, speaker_list, version='other', case='case_neg_1')


    #----------------------Violin Plots -----------------------------------#
    #violin_plot (x4_list, construct_list, speaker_list, version='same', case='case_1')
    #violin_plot (x5_list, construct_list, speaker_list, version='other', case='case_neg_1')

    #plot_percentage(y_label="Number of constructs", x_label="Proportion of turn time/construct duration", title="Histogram OF Speaker Time", name="x4",data=x4_list)
    #plot_percentage(y_label="Number of constructs", x_label="Proportion of turn time/ construct duration", title="Histogram of Other Speaker Time", name="x5", data=x5_list)	


    #print (differential_analysis(x1_list, construct_list))
    #print (differential_analysis(x4_list, construct_list))
    #pdb.set_trace()
    #differential_analysis ( x1_list, construct_list, case='case_1')
    #differential_analysis ( x4_list, construct_list, case='case_4') 

    #----------------Plottting for constructs -------------------#
    #subject_analysis  (x1_list, construct_list, speaker_list, version='same', case='case_1')
    #subject_analysis  (x4_list, construct_list,speaker_list, version='same',case='case_4')
    #subject_analysis  (neg1_list,construct_list, speaker_list, version='other',case='case_neg1')
    #subject_analysis  (neg2_list,construct_list ,speaker_list, version='other',case='case_neg2')

    #plot_histogram(y_label='Number of constructs (Total='+str(len(x1_list))+')', x_label='Number of Speaker-Turns/construct', title='Histogram for number of Speaker-Turns', name='uttereance_case1', data=x1_list)
    #plot_histogram(y_label='Number of utterances', x_label='Number of Utterances/Event', title='Histogram for number of utterances', name='uttereance_case2', data=x2_list)
    #plot_histogram(y_label='Number of utterances', x_label='Number of Utterances/Event', title='Histogram for number of utterances', name='uttereance_case3', data=x3_list)
    #plot_histogram(y_label='Number of constructs'+str(len(x4_list))+')', x_label='Number of Speaker-Turns/Construct', title='Histogram for number of Speaker-Turns', name='uttereance_case4', data=x4_list)
    '''
    #-----------------------------------------------------------------#
    plot_histogram(y_label='Number of constructs', x_label='Number of constructs/utterance', title='Histogram for number of constructs', name='construct_case1', data=y1_list)
    plot_histogram(y_label='Number of constructs', x_label='Number of constructs/utterance', title='Histogram for number of constructs', name='construct_case2', data=y2_list)
    plot_histogram(y_label='Number of constructs', x_label='Number of constructs/utterance', title='Histogram for number of constructs', name='construct_case3', data=y3_list)
    '''
    #differential_analysis ( neg1_list, construct_list, title='Nunber of Speaker-Turns for other speaker',case='case_neg1')
    #differential_analysis ( neg2_list, construct_list, title='Number of Speaker-Turns for other speaker',case='case_neg2')

    #plot_histogram(y_label='Number of constructs (Total='+str(len(neg1_list))+')', x_label="Number of Speaker-Turns/Event", title='Histogram for number of Speaker-Turns of the other speaker', name='uttereance_case_neg1', data=neg1_list)
    #plot_histogram(y_label='Number of constructs (Total='+str(len(neg2_list))+')', x_label='Number of Speaker-Turns/Event', title='Histogram for number of Speaker-Turns of the other speaker', name='uttereance_case_neg2', data=neg2_list)


    #---------------Plotting with respect to turns -------------- #

    #plot_turns (y1_list, turn_speaker_list  , version='same', case='case1')
    #plot_turns (ny1_list, turn_speaker_list, version='other', case='case1')
    #plot_turns (y2_list, turn_speaker_list  , version='same', case='case2')
    #plot_turns (ny2_list, turn_speaker_list, version='other', case='case2')
    #turn_duration_list= np.concatenate (np.array(turn_duration_list))
    #plot_turn_length(turn_duration_list, turn_speaker_list, case='case1')

    return 

for idx, items in enumerate(folds):

    res = np.load (os.path.join(root_dir,items),allow_pickle=True).item()


    analyze(res)

    if idx == 0 :
        break
# Out:
# /home/sas479/.local/lib/python3.5/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# > <ipython-input-1-1b7abd39dd9a>(811)analyze()
# -> audio=res['audio']
# (Pdb) text
# array([array(["(xxx) Hey, I'm making brownies.", 'Oh, cool!',
#        "And you don't get any.", "I don't do that.", 'Right.',
#        'So that, yeah that was', 'a good example of', 'you guys (uhm)',
#        'not getting along.', 'And then it ', 'got blown ', 'way out of ',
#        'proportion.', 'Both of you ended up getting ',
#        '(uhm) very angry.', 'Yeah, I got angry because that was...',
#        "That's so stupid. You can even ask Hayley. She was sitting right there when you said it.",
#        'And she said okay. Well how about anyways?',
#        'Well she said to him that I said thatt. And then me and her started laughing.',
#        'And Dawson just looks at me like that, and does this little thing.',
#        'But Dawson tends to do things like that a lot .',
#        "I don't pick fights with him. I don't start anything.",
#        "It's more, he's like...", 'Like when', 'I wanted a dog,',
#        'which I still do.', 'But when I first brougt that topic up,',
#        'just to rub it in my face, he came up to me and said hey Emily.',
#        "Just to be clear, you're not, we're not getting a dog at all, whatsoever.",
#        "Just so we're clear.", 'He comes up to me and he does that.',
#        'Where he is.', 'Just to rub it in my face and make me get mad.',
#        'And then if I just ignore it, he keeps coming up and doing it.',
#        '(xxx)', 'Right, yeah.', 'If I say something like',
#        "(uhm) you don't know that, he'll go yes I do cause I just talked to mom.",
#        'Or something like that.', "Right and that's not ", 'his place',
#        'to...', 'Get involved.', 'To get involved or ',
#        'to take the role ', 'of...', "Deciding what's gonna  happen.",
#        'of...', 'parenting.', 'So...', 'What,', 'what do you think',
#        'I can do', 'to', 'help out the situation', 'where you and Dawson',
#        'are concerned?',
#        'Well like if you were sitting out there and you hear',
#        'Dawson say something to me or ', 'I say something to him that',
#        'could start a fight just say hey!', 'You two just',
#        'go away from each other.',
#        "Like sometimes I'll be in the kitchen", 'getting... ',
#        'He had the bag of Cheetos.',
#        "And Hayley's like hey can I have some (xxx) Cheetos? And I said yeah.",
#        "That, they're for everybody. And she goes hey, can you get me a bowl? I said yeah.",
#        'Dawson was there',
#        "making his brownies and stuff, so he's doing that and I grab the Cheeto bag. He's like hey no, I was eating those.",
#        "And I said I'm just getting a bowl. So I grabbed (xxx) and I dumped it in there.",
#        "He's like don't take stuff away from me when he's on the other side of the counter",
#        'and the Cheetos are right there just laying there.', 'Yeah.',
#        'And so I walked in there and I gave them to',
#        "Hayley and that's when he came in and said his", 'thing.',
#        "That I don't get any brownies,",
#        'which I knew it was gonna be that way. I was about to say hey.',
#        'Ok then. I can just make my own.', 'Yeah, you could. ',
#        'Cause you know how.', "Yeah and like I'll make...",
#        "Like I'll make lava cakes or something like that.",
#        "He always eats 'em.", " I'll make a cake or something.", 'Yeah.',
#        "He'll eat it.",
#        'And I never say hey Dawson, you have to ask me before you have that.',
#        'Right.', 'And all...', "All I've tried to do",
#        'for the past while is be nice to him.',
#        "Like my old phone case, I could've just said you know I'm going to keep this or I'm going to give it to one of my friends who has an iPhone.",
#        'But no. Instead I took it and said here you go Dawson.',
#        "You don't have a case for your phone. You have no protection",
#        "and I don't want you to risk having",
#        'Mom having to pay more money for it.', 'Right.',
#        'So I gave him that.', 'And...',
#        "And I didn't get a thank you or anything out of it.", 'Yeah.',
#        'Be...', 'But...',
#        "But Dawson was around Victoria. When he's around Victoria he tends be groouchy cause he just wants it to be him and Victoria.",
#        'Yeah.', 'Yeah.', "And nothin' would've happened last night,",
#        'which is upsetting,',
#        "Very upsetting for him. that's why that's when",
#        'As soon as he came in crying I ',
#        'I just walked up to him and said',
#        'Do you need a hug and he said yes and then I ended up giving him a long hug',
#        'Then I talked to him about it', 'And I thought that was ',
#        'Beyond', 'Nice of you', 'And then what happened',
#        'To do especially', 'After how he ', 'Treated you',
#        'I think I thought that took', 'That showed me that you are very',
#        'Caring ', 'And you put everything aside ', 'To be ',
#        'Compassionate ', 'For Dawson', 'And I think that showed because',
#        'Then last night ', 'He told us both ', 'Goodnight and that he',
#        'Loved us', 'This morning he said', 'Same thing',
#        'And he gave me a hug this morning', 'Ya so that ',
#        "My dad's always taught me its",
#        'Good to be the bigger person like when JP says',
#        "Well if he' s not gonna be nice to you just do be nice to him",
#        'Ya ',
#        "But that's not being the bigger person that's being the smaller person ",
#        'Right ', 'You always want to be the bigger person', 'Because',
#        'If you said to not be nice to them then ',
#        "They're just gonna choose the same but if you be nice",
#        "It's gonna rub off on them eventually", 'Right',
#        'So (ju) (er) for (uh)', 'Solution should we try to', '(uhm)',
#        'Sit you and Dawson ', 'Down to talk ', 'When ',
#        'On a night or day when theres ',
#        'Not been any fighting so that way', 'Everybody starts out ',
#        'And is ',
#        "I wouldn't say just this week because it's been a pretty rough week for Dawson",
#        'Calm', 'Ya', 'Starting off already',
#        'So you think maybe starting', "Next time I'm with you",
#        'Next time and then maybe ', 'I know he goes to his ',
#        'Therapist tonight ', 'And you meet your', 'Therapist', 'Tomorrow',
#        'But (uhm) we can ', 'We can be getting some ideas ',
#        'You and I can be getting some ideas ', 'So that when ', 'It ',
#        'Comes around ', 'When you come back on', 'My time',
#        'That we could talk about it and then',
#        "When you're on your dad's time ", 'I can',
#        'Have Dawson be thinking ', 'Of things and ways', 'So that he ',
#        'Comes to the table ', 'Prepared', 'As well', 'And then ', 'Ya',
#        'So all three of us have our own ', 'Opinions and ideas ',
#        'And we can somehow ', 'As a family', 'Come together with ',
#        'What is going to work ', 'And', 'Ya', 'What', '(uhm)',
#        'Consquences',
#        'And I asked Dawson what  his favorite color was and he said black so when we go to Walmart I wanna look for',
#        'Like a soft black', 'Big role',
#        "Because for his Christmas present because it's probably going to take me a while I want to crotchet him a blanket ",
#        'Wow', 'That would definitely take a while', '(laugh) ya',
#        'But it will give me something to do',
#        "And with every stitch even if I'm mad at him", 'Ya',
#        "There'll be love and care and sometimes mad", 'Being very angry',
#        'There you go', 'You might be able to ', 'Stitch a lot',
#        "When you're ", "Angry but it'll go pretty fast", 'Ya',
#        'Ok next prompt is helping out our own house',
#        "I don't think that's necessarily a problem I think it's more",
#        'I said', 'I said that one ', 'As like a good thing',
#        'Because as a comp-ya it was like a ',
#        "That's what I said too cause I help out around the house a lot",
#        'Ya', 'Dawson on the other hand', '(hmm) not so ', 'No nope'],
#       dtype=object),
#        array(['School. It just adds up to a lot of hours.', 'Yeah.',
#        "So that's why I get so concerned .", 'Yeah.',
#        "I mean that's why I was saying I don't really, like even though it techincally has the same effects, like school. It's just like...",
#        'I know.', "It's just unavoidable, like you know?",
#        'I can try to work faster, but I can only go so...', 'I know.',
#        "But you know like, even this other thing why I get upset is like, can you use the dictionary? We'll look up one of the definitions. You know, that's why...",
#        "And it just doesn't...", "It's like,",
#        "it's like five times as long cause all you have to do in Google is just, you know, do defined.",
#        "Well is it cause you're not practicing", 'though?',
#        'I know how to do a dictionary though.',
#        "No, I know. But is it cause you're speed is slow is because you haven't practiced a lot?",
#        "Well it's just that I have a ton of defintions to do. It's like, cause you have to do two definitions per term and then I have 50 terms.",
#        'I dont know. I could look up 30 really fast.',
#        'You think how we do it in the quiddler...', 'Yeah, but...',
#        'but the, most of the definitions are not simple things like walk. You know like...',
#        'Dictionary.',
#        "To move with legs, you know. I'ts not like that. It's like...",
#        '(laugh)', 'You know like stuff like...', 'To move.',
#        "like Colombian Exchange and stuff like that. That's just like,",
#        'I see what you mean.',
#        'has these massive defintions that take like ',
#        'at least a minute to write each', 'Yeah.',
#        'and that just adds up.',
#        'So screen time. So if we take out the homework ', 'part.',
#        "Let's say we take out the homework part, right?", 'Then (uhm)...',
#        'We talked about this before how, was it two hours that we had agreed on that was acceptable? Because that still seems like a lot',
#        "I don't really remember.", 'Yeah, I...', 'everyday.',
#        'I mean, it just varies.', 'It was on a weekend.', 'I know.',
#        "It's just cause like,", 'the homework is just ',
#        "varies so much. On some days it's like nothing and on some days it's like just",
#        'into like 10.',
#        "Well this would be good to define before summer too right? Cause then you'd have...",
#        'Yeah.', "You won't be doing any schooling. You have time (xxx).",
#        'More time.',
#        'I think during summer two hours per day is a reasonable expectation.',
#        "Do you think that's a...? (uhm) And that includes everything like Ethyl Stuido.",
#        'But...', "Yeah, but I just don't know about like...",
#        "I dont remember the name of your game. What's it called?",
#        'Geometry Dash.', 'Oh, thank you. ', 'I was like trying to',
#        'Yeah.', 'think about that.', 'So...',
#        "It's just hard to tell honestly cause there's some days where I can do stuff with friends and hang out and there's other days where I'm just going to be bored, you know what I mean?",
#        'Right.', 'But I think,', 'I think',
#        'two hours and then not having roll over would be acceptable.',
#        'Cause if you had roll over, then you could have like 4 hours potentially, which is way too long for your eyes.',
#        'Yeah.', 'Yeah, I... what about phone though?',
#        "Because there's times when I'm just texting my friends and I've like,",
#        'I,', "(sigh) I just don't feel like ",
#        '5-10 minute sessions should count in too much.',
#        "As long as you're not playing games, I'm ok with the texting",
#        'Yeah.', 'on your phone.',
#        "Yeah, I don't... I  have literally one game on my phone. I almost never play it.",
#        'But',
#        "that's, the one thing that you do on your phone a lot is screen time is like looking for cards.",
#        'Yeah, sometimes I just get...',
#        'But I think that should cound in the screen time.',
#        "Ok, sure. That's fair.",
#        "If you're looking for cards and you do it for a half hour, that's part of your two hours.",
#        'What about listenting to music?',
#        'Like not listneing to music as in (xxx) and like looking for music?',
#        "Cause that 's pretty much looking at the screen, but...",
#        "I think that's...", "It's much more audio",
#        "related. I'm not so fixated on the srceen.",
#        "But you're looking...", "Well, I don't know. That's",
#        'hard to say',
#        "cause I think listening to the music while you're doing something else is cool.",
#        'Yeah.',
#        "Like if you're reading while you're listening to music, that's great.",
#        "But you're not. You're", '(xxx)',
#        'I just like searching for new music though.', "I don't...",
#        'Can we include that in the scereen time?',
#        "Sure. I mean it's just hard to say cause like",
#        'on a busy day that seems perfectly reasonable, you know?',
#        'But like',
#        "during this summer, there's some days where I just have nothing to do and I just...",
#        'Well, you know...', 'Well, get this. How about', '(xxx)',
#        "If you're waiting for something, like we're waiting for an appointment. You're waiting for Isaac to come over or something like that",
#        "Yeah, but it's usually at home", 'you could look for music.',
#        'like transition periods.', 'Transition periods.', 'Like,',
#        'you know like,',
#        "I guess it's no longer an example this year, but like",
#        'inbetween you know like,',
#        'like 10 minutes inbetween (xxx) in school. Something like that.',
#        "Right, like well we're trying, too.", 'Or like',
#        'when I finish a shower at', '9 and', 'you know',
#        "I'm about to go to bed, but I don't (xxx).",
#        "We're supposed to... Remember that 8:30 rule though? What about that? ",
#        'No.',
#        "It's not workin' out. I agree the 8:30 rule's not workin' out.",
#        "I think there's so many exceptions that just like...", 'Well...',
#        "Especially during summer where I don't need to wake up early.",
#        'I can understand',
#        "There is evidence though that you shouldn't look at screens before you go to bed.",
#        'Yeah.', 'What do you think', 'about ',
#        "8:30 rule during school, but I don't think it really should apply during summer cause I'm waking up so late.",
#        'Yeah, I think', "I don't think it should apply during",
#        'How bout like,', 'how bout like 9:30 rule?', 'The week',
#        'that is another thing too, like...', '(uhm)',
#        "I think 9:30's fine.", 'But would you', 'monitor that yourself?',
#        'Yeah, I guess.',
#        "I'm really tired at night. You knew about that.", 'Sure.',
#        'So... (uhm)', 'I think the two hour,',
#        'I think it will actually be easier. It will make me feel better in summer',
#        "cause I know that you're on your iPad all day at school.",
#        'Yeah.',
#        'So it makes me feel better kind of if you just only have two hours of',
#        'screen time ', 'during the summer. Would be like',
#        'less than you have now.', 'Yeah.',
#        'And then I guess we could look at it again in the fall.', 'Yeah.',
#        "But when we're travelling,",
#        "that's transition time. You could look for music if you have wifi.",
#        'You can...',
#        "And that's time that you could do Geometry Dash too, cause...",
#        "Yeah, I don't really wanna... I'm not bringing my computer on the trip.",
#        'Traveling.',
#        "No, I mean, you can do it on your phone, can't you?",
#        "I mean, I could. I'm not as good on my phone and there's things I'd rather be doing. I don't know.",
#        'Ok.', 'Ok.', "Well that's ok.",
#        'I should figure out how to spend my time (xxx).',
#        "Maybe I do want to bring my... No, I can't bring my computer.",
#        'I feel ok about screen time.', 'But I think',
#        'I just feel more emotional about screen time.',
#        'You know what I mean?', 'What ya mean?', 'Like I think',
#        'I worry about your health in that issue most.',
#        "Like spending money, I don't feel like you're gonna be",
#        'hurt by that. But screen time, I feel like it can actually hurt your brain and your body.',
#        'So that makes me feel more emotional about it, like...',
#        "Don't do that cause it's more scary. But spending money, I'm like oh you're learning over time how to do that. That doesn't make me like crazy.",
#        'Yeah.',
#        'Are we supposed to use the 15 minutes to discuss both or just one?',
#        'Please use the whole 15 minutes.', '(uhm)',
#        'Try to reach a problem with both issues.', "Ok, let's do it.",
#        'Ok, so...', '(xxx)',
#        "Do you want...? Let's move to spending money.",
#        'I think screen time sounds pretty good now.', 'Yeah, ok.',
#        "I mean, it's just harder in the school year.",
#        "I know. And the thing that makes me crazy is I have this emotional thing too with it because I feel like I don't spend any time with you.",
#        '(mhm)',
#        "So like when I come home and you're already doing homework and then you do screen time, I never get to talk to you.",
#        "Yeah, but from my perspective it's like,", "that's like,",
#        'what I ', 'enjoy.',
#        "I'm not saying like that (xxx), but it's my hobby and that's...",
#        "It's your hobby.", 'Yeah.',
#        'I totally get it, but do you see what I mean? I feel desparate for time with you.',
#        ' Yeah.', 'Yeah.', "Cause then I'm like...",
#        "Yeah, it'll be much easier during the summer.",
#        'I know, but do you know what I mean though?', 'Yeah.',
#        "So it's like we used to play games and do other stuff",
#        "and now that's taken up by screen time.", 'Ok.',
#        "So let's talk about spending money. What do you have to say? We already had a big discussion about this earlier.",
#        'Ok.', 'I know, I know.',
#        "It's the thing we argue about the most though.",
#        "That's, I felt like...", 'Yeah.', 'Well, not the most, but...',
#        'Yeah.', 'I brought up the issues. (laugh)',
#        "I'm sure you did, too.", 'But the spending...',
#        "And that's pretty much most of what I put down.", 'Oh, really?',
#        "Like back talk is another thing I did a bit. I don't know.",
#        'Oh! (laugh)', '(laugh)', "I don't really remember honestly.",
#        'Yeah. Well, the spending money',
#        'it has to do about magic, right? Ccause Pop and I are worried that you have this sole interest.',
#        'Yeah, we already talked about this, but like...', 'I know.',
#        'I...', 'This might sound really corny, but like...',
#        "But I'm worried that you...", 'Yeah.',
#        'The summer though, I mean like doing the summer reading program or something. Could you do that?',
#        'Yeah.', 'I guess.',
#        "There's just, I'm in the inbetween thing where's it's like all of the books",
#        'I know (xxx).', 'are just terrible.', 'Yeah.',
#        "They're so bad. They just have no...", "They're just like...",
#        'Well you could...', 'The thing is that (uhm)', '(laugh)',
#        'if you showed us,', 'seriously, if you showed us that you had',
#        'even a slight interest in other things,',
#        'I think it would make us feel much better about you spending money.',
#        "No, I do. I've been interested in music production and Geometry Dash.",
#        'Totally.',
#        "But those both seem like singular cause they're on the computer like that.",
#        "There's nothing like physical like building.",
#        "I know, but they're not really the same thing.",
#        'No, but I mean away from screens.', '(mhm)',
#        'Is there, you know, any interest like reading?',
#        'Or doing science? Or the atoms? Or anything like that, you know?',
#        '(uhm)', 'Something different.', 'Or math.', 'Yeah.',
#        'I mean, it just (xxx).', 'Yeah, I mean...',
#        'It is an exorbitant amount of money. (laugh)',
#        'Yeah, but I mean...', 'You know, like?',
#        "I didn't really talk about this before. I guess we can talk about this.",
#        'You can argue', 'you know how',
#        "you're buying enjoyment. You know, how is that different from",
#        'buying tickets to ', 'a concert, you know what I mean?', 'Yeah.',
#        'And you get to keep it', 'and use it over and over again.',
#        "And if you're getting this",
#        '(xxx) You already started a new deck.',
#        "No, I'm working on the same thing.", 'No.',
#        "I've been working on the same thing for like", 'months now.',
#        'No, I know, but you have a lot of previous decks that you had to get.',
#        'Yeah, they were like...', '(xxx)',
#        'Those were like before I sold a lot of them.',
#        'Those were like before when I was any good.',
#        "Well I know it's always changing, right?", 'Yeah,',
#        'But what do you think would be reasonable as far as spending money? Do you think this percentage thing is working out for you?',
#        'House sitting?', 'Definitely this month.', 'Christmas.',
#        'Could we track it',
#        "if you wrote down the money you're spending?", 'Ok.'],
#       dtype=object),
#        array(['So the phone use and fighting with brother and sister.', 'Ok?',
#        'We started technology.', 'You should (xxx).',
#        'So it says right here, it says try to reach a solution to both issues.',
#        'So...', 'We could apologize to each other.', 'Right.',
#        'What about with the phone use?', 'This is how',
#        'I was saying you should ', 'find other things to do',
#        'What should you do then ', 'I should ', '(laughs)',
#        'No, I should jump on the trampoline. Maybe even play video games with my sister.',
#        'Maybe. That would be fun.', 'So...',
#        'What are some big road blocks, Tanner, that helped that?',
#        'What are road blocks?', 'Roadblocks like barriers.',
#        "What are barierrs? Is that what you're gonna ask next?",
#        'So like things that come in the,',
#        "the middle of a situation. Like let's say for instance ",
#        'I ask you and your sister to stop fighting, right?', '(mhm)',
#        "And you keep fighting. And I ask again, and I ask again. So there's a barrier right there that is because you're not listening.",
#        "I don't do that.", 'Yes you do.', "(laughs) No I don't.",
#        'Yes you do.', "No. (laughs) I don't.",
#        "That's why we're studying.", "(sigh) No, I don't.",
#        'Alright, so what about', 'fighting? Ok, so phone use.',
#        'So we need to find a solution.',
#        "Is to do other things. Is that what you're saying?", '(mhm)',
#        'Like what else could you do?',
#        'You could bounce on the trampoline.',
#        'Exp-((breathes loudly))-lore!', 'Explore what?',
#        '(laughs) You ask me what now? (laugh) ',
#        'I never said I knew. Just explore whatever you can find. Like just play outside, I guess,',
#        'in other words.',
#        'So then did we come up, overcome the barriers?', '(uh huh)',
#        '(yawns) (xxx) laughs',
#        'How bout this? How about when you and your sister are on the trampoline ',
#        'bouncing up and down...', 'I, we are never together.',
#        'So, and then you start fighting and you start putting your hands on each other. So what do you do then, Tanner?',
#        '((loud singing))',
#        'What do you do? What would be a good thing to do?', '(uh)',
#        'To stop and get off and leave sissy alone.', 'Right.',
#        "But you know how sissy doesn't like to be on the trampoline by herself and she want's to hang out with you? So what's a way that you two could hang out with each other",
#        'without it turning into a fight?', 'How about...',
#        "It's not possible because no matter what we do together we start a fight.",
#        'Why is that?', '(yawns)',
#        'I would have to give you like 20 reasons,',
#        "and I don't want to name that many.", 'You need to.',
#        "You need to name 'em.", 'Ok.', '(uhm)',
#        'Try, find, think, decide.',
#        'Ok. Try what what? What are we trying? What are we gonna try?',
#        'To reach the solution of most issues.',
#        'Ok, what are the issues?', '(uh) (xxx) (laughs)',
#        "What are the issues? They're down there on the little piece of paper.",
#        'Ok. Phone use,', 'fighting with brothers and sisters.',
#        'There, I just named both of them.',
#        '(uhm) Think of any roadblocks ',
#        'or barriers you may... Oh! We could (stuttering) grab berries together.',
#        'We atleast get along with that.', "Yeah, that's the good one.",
#        "Ok, what's another thing that you could do?", 'And...',
#        'We could play in the pool. We sometimes get along.', 'Yeah.',
#        "But what happens when you guys start gettin' in each other's space?",
#        'I just did revenge because last time... (laughs) Remember last time we were on the pool and then I pushed her and then she did a backflip off of her floatie?',
#        '(uh huh)',
#        "I just remember she did that once to me and I couldn't breathe under water.",
#        'But was that right, Tanner?', 'Yeah. In other words, yeah. ',
#        'It was right?', 'She can put... (xxx)',
#        "(laughs) And I didn't even believe her that she couldn't breathe.",
#        'But was that right though, to do that?', '(uhm)',
#        "What was another thing that you could've did besides do that?",
#        'Besides paying her back for what she did to you?', '(uhm)',
#        'What could you have done?', 'I could give her money.',
#        "No, what could you have done? Maybe you could've called and said Mom...",
#        '(laughs)',
#        'I tried to. Well, you just went (sigh) would you two get along? (xxx) (laughs) ',
#        'But I tried to get you guys to get along, right? ',
#        '(xxx) (laughs) ',
#        "So but there is one thing Tanner that I want you to know. That when your sister needs you, like when she doesn't want to be upstairs alone when she takes a bath and you're in the bedroom,",
#        '(mhm)', "you know, so that she knows that somebody's upstairs?",
#        '(mhm)', "I really appreciate it when you're there for her.",
#        'Ok.', "I like that. It's very nice.", '(mkay)',
#        'Is there other nice things that you could do to be nice to your sister?',
#        '(mhm)', 'Like what?', 'Like', 'talking to her.',
#        'Talking to her how?', 'We could play rock paper scissors.',
#        'Right, you could also play connect.',
#        'Rock (laughs) paper scissors, shoot.',
#        'You could play Connect Four.', 'Oh, is that a paper? (laughs)',
#        'You wanna play rock paper scissors with her? Connect Four with her?',
#        'I wanna play checkers.', 'Huh?', 'Checkers.', 'Checkers?',
#        'Yeah.', "Oh, we don't own it anymore.",
#        'No, but we could another one.', "It's not at Dollar Tree though.",
#        '(xxx)', "Actually, it's at... actually (uhm)",
#        'Chess is at Dollar Tree.',
#        'So now what about the phone use thing?',
#        "So when Mommy says that you've had too much phone time, what do we do next?",
#        'We... (laughs)', 'Stop.', 'It helps me think.',
#        '((screeching)) (laughs)', 'Stop doing it. They can hear you.',
#        '(laughs)', '(laughs)',
#        "Well actually, it's kind of helping me think.",
#        "What'd you say again?", 'I said',
#        'and when I ask you to get off the phone?', 'We play board games.',
#        "Ok, what else? What's another thing that we can do?",
#        "We go to my friend's house.", 'There you go.', "We go to Eric's.",
#        'Yeah.', 'We play outside.', 'Yup.', 'We go on a road trip.',
#        "Ok, so but when I'm really really upset ", '(mhm)',
#        'is listening to me a good,', 'a good thing?', 'About ',
#        "the phone thing? Like when I ask you get off and you don't get off.",
#        'Yes.', "So it's better that you listen?",
#        'Yes! Everyone knows that! (laughs)', '(laughs)',
#        "You're just telling me already stuff that I know.",
#        '((clearing throat))',
#        'We could overcome these barriers by playing',
#        'nicely with each other.', 'We can listen to Mom.',
#        'We can find other things to do.', '(mhm)',
#        'And with your sister, you could...',
#        'when you have a problem with her, you can come to mom, right ?',
#        '(mhm)',
#        "But how about solving the problem all by yourself? What's a good way to solve the problem?",
#        '(uhm)', 'A good way to solve the problem ', 'would be to...',
#        'be to work it out.', 'On your own?',
#        'Instead of bugging mommy cause we gotta...',
#        'sometimes we have to (xxx).', '(mhm)',
#        "But what if you're all the way in Reedsports and we're all the way in New Mexico?",
#        'Why would you be in New Mexico?',
#        'And why would I be in Reedsport?',
#        'What if Dad blew up? (laughs)', 'Why would Dad blow up?',
#        '(xxx) (laughs)', '(laughs)', '(laughs) (xxx)', 'Tanner...',
#        'What do you like about the phone?', '(xxx) (laughs)',
#        'Tanner, what do you like about the phone so much?',
#        '(uhm) I like that (uhm)', 'that it talks to me.',
#        'It talks to you?', '(laughs)', 'It does not talk to you.',
#        'It does not.', '(xxx) (laughs)', 'Because of the what?',
#        'The sick.', '(xxx)', "(xxx) You're sick of it?",
#        'I also like motorcycles, so I could (xxx).', '(xxx)',
#        '(laughs) (xxx)', 'Alright.',
#        'Now that we figured out the phone use problem and the fighting with ',
#        'your sister...', '(mhm)', 'So...',
#        'we came up with finding a solution, which is to do other things.',
#        'Is to listen to Mom.',
#        'Think of any road blocks that could come in is when you and your sister are actually fighting.',
#        'Right?', "And I'm not there.", "So that's a barrier, right?",
#        'And so...',
#        'you decided how to overcome the barrier was by solving the problem yourself, right? ',
#        'So what about the phone thing? Is there something that you can do to decide ',
#        "to overcome the barrier without me bein' there?",
#        'Like can you take yourself away from the phone?', 'Yup.',
#        'I do it all the time.', "It's true.", 'Very true.',
#        "You've seen it when I think that it's time",
#        'that Austin gets home, I throw my phone. I smash it to the phone cracks. (laughs) And then I... (xxx)',
#        '(xxx) (laughs)', '(yawns)', 'Alright, so we...',
#        'Discussed everything.',
#        "We discussed everything. That's correct.", '(laughs)', '(laughs)',
#        'So, now what?', 'We could...', '(uhm)',
#        "What's your favorite thing about the phone?", '(uhm)',
#        'That it talks to me.',
#        "(laughs) I'm serious. It shows me this character. (xxx)",
#        'What draws you to the phone?', '(uhm) No.', 'The talking?',
#        '(xxx) (laughs)',
#        "I'm serious. You should see my wallpaper. It's awesome.",
#        'What draws you to fight with your sister?'], dtype=object),
#        array(["We could talk about these things, and it'll make you feel better.",
#        'Ok.',
#        "Not right this moment, but we could talk about them and maybe that'll help you sleep better.",
#        'Ok.', 'You know you can come to me if you have any problems.',
#        'Ok.',
#        "Do you think you can stop fighting me about going to bed and then we can work through whatever's troubling you?",
#        '(xxx)', 'Yeah?', 'Ok?', 'Making too much noise at home.',
#        'I... (uh) (laughs)', 'I may make too much noise for (xxx).',
#        'Yeah.', 'Sometimes you make too much noise for me.', 'Yeah.',
#        "I'm just a really loud person.",
#        'Yeah like running and bouncing off your walls.',
#        '(boing boing boing boing)',
#        'You think we can try not to do that?',
#        'Try to find calming, calmer activities to do inside the house until you go outside to play?',
#        '(hm)', 'I have been playing with my toys lately.',
#        'So what can we do to make less noise in the house?',
#        "I don't mind if you make noise durin' the day",
#        'when people are awake,', 'but everybody has different schedules',
#        'and you gotta be respectful of those schedules.',
#        'I guess I could play with my toys until I go outside.', 'Yeah.',
#        'Maybe we can set a certain time that you can start playing outside',
#        "like after 9 o'clock", 'so that the neighbors are awake',
#        "already so you're not waking up the neighbors.", 'Ok.',
#        "Maybe we can go get you another alarm clock cause I don't know what happened to your's.",
#        "I don't know how it disappeared out of your room.",
#        'So you can see the time all the time.', 'Ok.',
#        "What's other ways that we can try and be quieter inside the house?",
#        '(hm)', "I don't know.",
#        'How about not running through the house?', '(hm)', 'Ok.',
#        'I know you get excited and you just wanna get',
#        'speed racer to get from one place to the other.',
#        'So what would you like to do to help fix this?',
#        "(uhm) I don't know. (uhm) Maybe like...", '(hm)',
#        '(uhm) Maybe like', 'try to calm down my energy.',
#        'How are you gonna do that?',
#        "Well, my teacher says he's able to do it.",
#        'Ok, but how do you wanna try to do that? Are you gonna focus on something or?',
#        'Yeah, focus on something.', '(uhm) Trying', 'not to...', 'Well,',
#        'go really fast through the house',
#        "cause that's also how I hurt myself.", 'Yeah.',
#        'So slowing down inside might resolve more than one issue.',
#        "Won't be waking Sharaya up so easily.", "You won't be sp-",
#        'making the whole house shake with you bouncing around.',
#        "You won't be", 'hurting yourself.', '(uhm)',
#        "You won't be hurting other, the animals by accidently stepping on them.",
#        '(uh) What else?', 'So...',
#        'if we can calmly walk through the house and learn how to focus.',
#        'So...', 'what do you wanna use as a focal point?',
#        "I don't know. Maybe like",
#        "something that doesn't get me so excited.", 'Ok.',
#        'Any suggestions?',
#        'I could focus on something that makes me sad.',
#        "Well, that's not good.", 'Yeah.',
#        "Cause it's really a really happy moment ", 'or angry one',
#        'or really sad one.', "We don't want to focus on sad things.",
#        '(xxx)', 'But anything that makes me happy makes me get excited.',
#        'Ok.', 'Could we use like a toy or something to remind you?',
#        'Or like',
#        'a squishy ball, if you still know where your squishy ball is,',
#        'to remind you to walk calmly?', 'Yeah!',
#        "So you know when you walk through the house that that's",
#        "what you're supposed to do?", 'Yeah.', 'Ok.',
#        'How about yelling in the house in the morning?', 'Stop it.',
#        'Why do yell in the house in the morning?',
#        "(sighs) I don't mean to. I don't mean to be yelling in the house.",
#        'I just', 'play really loud.',
#        'Maybe we can make more activities for you to be able to do in the backyard?',
#        'Ok.',
#        'You have to help me set it up. What kind of activities would you like to set up out there?',
#        'Maybe like a little like...', '(xxx)',
#        'training course or something like that.', 'Ok.',
#        'As in something or an obstacle course.',
#        'What kind of obstacle course?', 'Like one that requires', '(xxx)',
#        'You can run all your energy out outside.', 'Yeah.', 'Speed.',
#        'Athleticsm, a little bit.',
#        'So what else would you want to put out there to help you?',
#        'Maybe like ', 'a little race area.', 'A race area?',
#        'How about like soccer or something?',
#        'Get you a soccer ball or something you can kick around in the backyard?',
#        'Yeah, that works too.', 'What else would you wanna',
#        'set up so that, to help you', 'relieve your energy?',
#        'Maybe like a ', "basketball thing. No, that wouldn't work.",
#        '(uhm)', "I don't know.", '(hm)', 'Maybe...', '(hm)',
#        "(hm) Maybe... I don't know.", 'Maybe...', 'Maybe an...',
#        'obstacle course that for a different purpose.',
#        'One that makes me have to', 'use those athleticsm stuff.',
#        'More athleticsm and less speed', 'and more timing.',
#        'Can you think you could think of anything that would make you have to focus?',
#        '(uhm)', 'How bout not running in the house?',
#        "(mh) Not so much. It's somethin' to help you learn how to focus.",
#        'Maybe like (um) something that you could...',
#        "It's repetitve. The...", 'You might enjoy it.', 'Maybe...',
#        'Maybe a training dummy,', 'dummy,', 'which I can practice',
#        'since', 'stuff from.',
#        'Like set him up wherever I want for different things.',
#        'What do you mean by a training dummy?', 'Like set him up as...',
#        '(xxx)', '(xxx) in certain positions to where I...',
#        'like in block stuff and stuff.',
#        'So would you be violent on the training dummy?',
#        "Yeah, plus that'll hel- also help me get out my anger.", 'Yeah.',
#        "You think that if we'd set something up in the backyard for you to be able to go do in the mornings,",
#        'stuff you could learn to be quieter in the house?', 'Yeah.',
#        'But maybe the training dummy just for ', 'anger management (xxx)',
#        '(xxx)', 'And (uhm)...', 'The...', 'And...', 'And then...',
#        '(uhm) something else.', 'Maybe like', "I don't ", '(xxx)',
#        'Something else that can help me', 'being all quiet in the house?',
#        'I think', 'maybe', 'we put',
#        "your shoes on the back porch, so that you're not stomping through the house with your shoes on.",
#        "You're not as loud when you're bare foot.", 'Ok.',
#        '(uhm) Make a little ',
#        'shoe cubby or something on the back porch for you.', 'Ok.',
#        "As far as you screaming in the house, I'm not sure how to ",
#        'fix that one.'], dtype=object),
#        array(["Now you've gotten too big for that, so what else?", 'We ca-',
#        'You can just be like', "alright, that's it. Go to your rooms.",
#        "And if we don't listen...",
#        "And what if you're fighting with the person that lives in your room?",
#        "You're just like a Destiny child. (laughs)",
#        '(uhm) Then you put one of us out in the living room.',
#        'With me, so I have to hear it?', 'You just put on some earbuds.',
#        "Yeah. (laughs) That's what I'll have to do all the time. Put on my head phones. (sings)",
#        '(yawns) Ok.',
#        "What kind of consequences you think there should be if there's constantly fighting?",
#        "If they get... wait, wh- what's the first one that we're supposed to talk about?",
#        "Showering, and what's gonna be your consequence for not showering.",
#        'I gotta eat a bar of soap.',
#        "Being dirty? You're gonna eat some soap?",
#        'Just kidding. That would be nasty.', 'Spray you with the hose.',
#        'Yeah, spray me with the hose.', '(laughs)',
#        'Shower! (spraying sounds)', 'And clean your filthy room!',
#        'It smells like dirty feet.', '(xxx)', '(xxx)', '(xxx)',
#        '(laughs)', 'Ok. (uhm)', 'What else?',
#        "What should be your consequence for real for not takin' a shower?",
#        'Or cleaning your room?', 'What should we do?',
#        "I don't get an allowance.",
#        "I give you money all the time. That's your allowance, girl.",
#        'I know.', 'So', 'for not showering?', 'Yeah.',
#        "You're never gonna get allowance.", 'I shower.',
#        "Not, I have to repeat it to you a thousand times throughout the day. I'm like Electra, I need you to take a shower. Electra, I need you to take a shower. Electra, I need you to take a shower.",
#        'Ok. I- If you have to...', 'Ok, ok, ok.',
#        "You know that. You're like I did! I took a shower yesterday!",
#        'I did take a shower. I really did.', '(laughs)',
#        "Ok, I believe you that you took a shower yesterday at Lily's. But sometimes",
#        "you say that you do (xxx) and really, I've been there. I live there. I don't leave the house, so.",
#        "I know that you haven't taken one all week.", 'And...',
#        'I just took one yesterday.',
#        "I'm not sayin' that... I know yesterday. But the day before that, it was probably about a week.",
#        'No.', "It's ok to be a hippy child, but sometimes we have to...",
#        "I'm a Destiny's child. What you mean, girl? What you mean?",
#        "Destiny's child? Fine. Destiny's child then.",
#        "What else, Destiny's child? Or Kesha's child?", '(uhm)',
#        "Great. (uhm) Anyways, so I'm like yeah.", 'Yeah.',
#        "Ok. How can I make you take your showers? Cause you don't like to take them. And you (uhm) take them once a month.",
#        'Yeah. What if... what if',
#        "you had to tell me when to take a shower and I wouldn't do it?",
#        "And that would suck and I would throw a bucket of water on you and grab (xxx). No. (laughs) I'm just kidding.",
#        '(xxx)',
#        "(wretching) (xxx) vomit in the car. You're like you can't come over. My mom stinks really bad.",
#        'She got',
#        "hair all over her body. She lookin' like some big foot, and I don't know what to do.",
#        'I got to take a weedwhacker and whack her in time.', '(xxx)',
#        'Yeah.', 'Sprayed with a hose and weedwhackers. Whoo!',
#        'K, how do you even think you can get us kids to stop fighting?',
#        "I don't know. If I knew the answer...",
#        'You guys have to learn to become more...',
#        'We need to go to the (uhm),',
#        'where they make you guys work together.', "What's it called?",
#        'Homeless children.', 'No, not homeless children.',
#        'Where they do, you know, like connected activities and stuff together?',
#        '(uh)', 'Where you have to help each other.',
#        'You know, like through a rope thing and stuff? And a giant',
#        'obstacle course and you guys have to rely on each other and help each other go through it.',
#        'And you need more... (uhm)', 'We just need to like',
#        'spend more time together.',
#        "Yeah, what's it called though? Something building skills. Communication building skills and (uh) something else.",
#        'You should sign us up for that.',
#        'Yeah, you have to do it yourself too.',
#        'You have to do it yourself?', 'Is that what you just said?',
#        '(whispers)', 'Never.', 'Leave the room.',
#        'Ok, what else, Electra?', "(yawns) That's it.",
#        "No. What's for real gonna happen when you don't shower? Besides that your hair gets really gross and dirty.",
#        'I said', "(laughs) I'll eat a bar of soap.",
#        "You know that's not real. That you would not eat a bar of soap.",
#        "Cause you like to say you shower, but you don't.",
#        'Ok, Mom, you know what?', '(xxx)',
#        '(xxx) Right now. I did take a shower cause or else my legs would be hairiest.',
#        '(xxx) And I shave.',
#        "Look at that hair stickin' out of there. (laughs) No. I'm jokin'.",
#        'What?', "Yeah, see. That's been years. Don't lie. (laughs)",
#        '(laughs)', 'That is not off my leg.', "That's off of my head.",
#        "I know. I'm just messin' with you.",
#        "I'm not sure you're messing with me anymore.", '(uhm) Yeah.',
#        '(xxx)', 'You look like your mother.', 'Nope.', '(laughs)',
#        "I'm ju-", 'Yes, you do.', 'I look like you?',
#        'What can you do not to fight with your brothers and sisters anymore?',
#        'Or as much?',
#        "Just stop talking to them when they're being negative.",
#        'Yeah. Can you just walk away?', 'Yep. Walk away from the,',
#        'the negativity.',
#        "And go to my Grandma's house and live with her forever (xxx) and just get whatever I want.",
#        'With Grandma? And (xxx).',
#        "I'll live with Grandma so she spoils me and I'll be like",
#        'Hansel and Gretel and become really big.',
#        'And then Grandma will cook you?', "Yep. She'll cook me.",
#        'Like Hansel and Gretel, huh?', 'Did I just beep? Or you beeped?',
#        "I don't think that was one of us. I don't know. It might've been their's.",
#        'Their what?', "They're coming, I think.", "I don't think so.",
#        'Yep.',
#        'What kind of consequences do you think we should do with (xxx)?',
#        "You guys aren't getting along.", '(uhm)', 'Ground us.', 'Yeah.',
#        'But that never works. (laughs) Cause we end up going places anyways.',
#        "I'll take your phone. How bout that?", '(xxx)',
#        'Well that will never work if I (xxx). (laughs) No. Just kidding.',
#        '(laughs)',
#        "You better help your (xxx) eat the phone because I'm comin' for it.",
#        '(laughs)', "Just kidding. I don't have crack.", 'For days.',
#        'For days. (laughs)', "Dab on 'em. Dab on 'em.",
#        "Justin Bieber'd be like...", '(uft)',
#        "You're funny. How come you don't like takin' showers?",
#        'Because I wanna have dreads.', 'I want dreads.',
#        "I'm a dread be lover. (laughs) No, I'm just kidding.",
#        'You can have dreadlocks if you want.',
#        "I'm just kidding. No, that'd be nasty.",
#        "You don't like to brush your hair anyways.",
#        'I do like to brush my hair.',
#        "Just not the back, so we'll put the back (xxx).", 'No.',
#        'Dreads.', "I think you're already gettin' dreads back there.",
#        "No, I'm not.",
#        "It's already startin'. (laughs) You wanna just finish it off? (laughs)",
#        "No, it's not.", 'No. (laughs)',
#        "Then if I wanna get rid of the dreads, I have to shave my (xxx). And then I don't wanna be like Tory.",
#        'Yes.',
#        'Or you know what you do is just wait til it grows out and keep brushing it',
#        'and then as it gets like right here, then you chop all the dreads off.',
#        "You're a weirdo.", 'Why?', "I'm just kidding.", 'Beep.', 'Beep.',
#        '(mimicking siren) Oh, Kesha died in here.', 'Why? (laughs)',
#        "Electra, I'm psycho. She went", 'savage!',
#        "You just killed me off in your imagination? That's terrible.",
#        "I'm just kidding. (laughs)",
#        "Just kidding. I'm not a mean child.", 'So you (xxx)?',
#        "Yeah, and I don't like that. I wanna watch TV,",
#        'and I wanna become fatter.', '(whispers)',
#        '(xxx) Is that what you said?', 'Yeah.', 'Why?'], dtype=object),
#        array(['And learn to difuse yourself when you', 'get worked up.',
#        'Just have to walk away.', '(laughs)',
#        "Don't have to have a solution to the problem. Just walk away.",
#        "I know. It's just... (mh) Ok.",
#        'Road blocks are very a human encounter.',
#        "I always wanna be right, (laughs) and it's so annoying when she's right.",
#        'What does it matter?',
#        'Cause I have to prove my point (xxx) and then I get mad.',
#        "Well, that's the thing. Even if you're at that point where you have to prove your point,",
#        "she's never gonna agree with you just because she's stubborn too.",
#        "So it doesn't matter how right you are. She'll never agree with you.",
#        'Why do I have a stubborn little sister?', 'Cause she...',
#        'So that my stubbornness', "doesn't work. (laughs)",
#        "Well, she's not as stubborn as you are. That's for sure.",
#        "But she's stubborn. (laughs)", 'Oh, yeah.',
#        "(laughs) She's stubborn, and she likes to cry a lot.",
#        "She's emotional!",
#        "Oh my gosh. She's cries about everything though.",
#        'You get angry. She cries.', 'Well...', '(sighs)',
#        'She needs to learn how to play basketball with me',
#        "cause that's how I was taught to play. You're supposed to be aggressive, and I can't play basketball with her.",
#        '(xxx)',
#        "She gets mad, and she starts crying for no reason. And I don't even try to put my elbows into her. I just do a pivot, like you're supposed to do.",
# ...
#        "But we're not talking about when Mom and Dad",
#        "go out and do errands. I'm talking about the every day to day stuff.",
#        '(xxx)', 'Like I might not wanna just go out.',
#        "Well, do you think it'd be good if we sat down and",
#        'talked with everyone and', 'you express your feelings about',
#        'them barging into your room and we', 'No.',
#        "make a rule that they can't just barge into your room?", 'No.',
#        "You don't think that's a good solution?",
#        "No cause they s- they'd make fun of me.", "Then what's-",
#        "Well they wouldn't know that you set up-", 'said anything.',
#        'What if we just have a family discussion',
#        'With the starting of hey, Caleb- ', 'about fighting?',
#        'We can just talk.', '(uh)', 'Start it off with fighting.',
#        'Okay.', 'Do you think that would be a good-', 'Yeah.', 'No?',
#        'Yeah.', '(hm)', '(laugh)', '(laugh)', '(uhm) Yeah.',
#        "So that's how we overcome those barriers.",
#        "(xxx) if we're goin' to bed,", 'do-',
#        'do I ever give you trouble with that?', 'Yes.',
#        "Well cause sometimes you linger and you want hugs and kisses. And I give you those and then you're like I want a hug. And I'm like I already gave you a hug. Go to bed.",
#        'But-', '(laugh)', "Well I always linger cause it's like",
#        "I'm not quite tired",
#        "but there's nothin' to do now that you sent us to bed. So I sort of just stay in that",
#        'area', "and like don't",
#        "Yeah but when- when I say it's bed time, don't you think you should",
#        'wanna actually go to bed.', 'be- you should mind?', 'Yeah, I do.',
#        'I do like get in my pajamas and stuff.', 'I just linger',
#        "cause I don't", 'quite wanna go to bed yet.',
#        'And I like hanging out with you guys more.', 'I know, but',
#        'you get a whole extra hour besides the little kids.', 'Yeah.',
#        "So do you think it's a good idea if I say go to bed, go to bed? Cause I gave you a whole extra hour. I just now started that whole new policy",
#        'what like a week ago or two weeks ago?', 'Yeah.',
#        'I thought it was about time that you guys get a- ',
#        'you and Natalie both get to', 'stay up an hour later cause',
#        "you're not a little kid. You don't need to go to bed at 7 o'clock anymore or 8 o'clock.",
#        'Yeah.', 'So', 'if I ask you to go to bed,', 'can you go to bed?',
#        'Yeah.', 'Cause like',
#        "my solution would be to put you back down to the 7 o'clock bedtime if you don't go to bed.",
#        '(cough)', "That's not very nice.", 'Yeah,',
#        "but it's not nice if you don't go to bed.", 'Yeah.',
#        "I just don't remember (xxx) go to bed.", 'Oh, I did.',
#        'You (xxx) like 50 times or something.', 'I did- not 50, only-',
#        'I only put 14 cause one for each day.', "Yeah, it's like-",
#        "But I don't know.", "I did more than 14 on one of 'em I think.",
#        'Oh no, it was just 14.', 'Oh.', 'I did 14 on my couple.',
#        'This was really', '(xxx)',
#        'How many did you put for fighting with Selix?',
#        "Fif- 14. I should've put a thousand.",
#        'And then how heated was the discussion?', 'Moderate I think.',
#        'Oh I put it as five.', 'The highest?',
#        "Yeah cause you guys get so mad when we fight. I'm not taking them off.",
#        "Don't take them off.",
#        'Well I do get angry when you guys fight bec-', 'Yeah and so-',
#        "Don't touch that.", 'Caleb,',
#        "I already- I'm gonna stop now. (xxx) Whatever.", 'quit.', 'What?',
#        "You don't like talking about this?", 'No.', "I'm fine.",
#        "I know, but that- that was really hard cause I don't even know if it's been five minutes.",
#        'I know.', 'But do you think we went through each thing?', 'Yeah.',
#        'I mean-',
#        'Do you feel like we got a good solution for fighting with kids?',
#        'Yeah.',
#        'That we have a family meeting. We start talking about some of the stuff that-',
#        'Yeah.', "that's causing the issues?", '(uhuh)',
#        'Do you think it will really work?', 'Probably.',
#        'What do you think a roadblock would be for the (xxx) siblings if we sat down and',
#        'talked? Do you think anyone would care and listen?',
#        'Or do you think that would',
#        "They'd probably all start pointing fingers at me and be like-",
#        'help?',
#        'Turn it away from what the discussion was originally started as.',
#        'Oh, I looked at that hem. I thought you took off your things.',
#        'No.',
#        'Well how can we ever- do you think we could overcome those',
#        'Yeah.', 'barriers? Cause if',
#        "they're all saying it's all Caleb's fault. Caleb.",
#        "It's not all me.",
#        "I said if the kids say it's all you, all you. How do you think would be a good way to overcome those?"],
#       dtype=object),
#        array(["Yeah but when you're not there and Natalie's in charge, they all get along.",
#        'Only because she babies them.',
#        "Well maybe that's what they need.",
#        "I'm not talking about when yo- when we're gone.",
#        "I'm not gonna baby them.", 'You guys fight.',
#        "Well yeah, when you guys are here, it's okay.",
#        "When we're at home-",
#        'When Mom and Dad are at home, you guys fight too.',
#        "Fighting's how we settle our differences.", 'But',
#        'do you guys ever come to a good agreement?',
#        'Yeah, I raid their room.', '(laugh)',
#        "Caleb, we're supposed to be serious.", '(laugh) Okay.', '(xxx)',
#        'For real though. What do you think-',
#        'No, we- we rarely come to an agreement because it usually',
#        'becomes a pushing match before', 'anyone (xxx)',
#        "Don't play with those please.",
#        '(uhm) Do you think that maybe you can give a little and they can give a little? Instead of it being all your way or all their way.',
#        '(cough)', 'I mean they can get- I mean',
#        'the majority of the fighting is when',
#        "Simon just sits there and let's the girls come in the room",
#        'and like-', 'like one day I came home from school.',
#        'I expected my room to be the way I left it,',
#        'and they were sitting there playing, using a bunch of my stuff and they had moved all my stuff around',
#        'and it just frusturated me.',
#        "So that. And then you act as if it was like my fault or something or like I shouldn't have been mad.",
#        'Well-', 'Well,',
#        "do you know why? Cause you didn't come to me with the problem. You just decided to get mad at them and deal with it yourself.",
#        '(eh)',
#        "Do you think it would've been a better option for you to come and deal with it with me?",
#        'Yeah.', "Yeah it would've.",
#        'And we need to change that rule that one person gets entire say',
#        'cause half the time they do it just to spite me.',
#        "Say that I can't.", "But that's not-", 'Or like-',
#        "That's not fair if you always tell Simon no, the girls can't come in. It's his room too. It's not just your room.",
#        "I know, but the girls shouldn't be coming in the boys room. Just like if I ever go in there.",
#        'Like it-', 'You guys, everyone flips out',
#        'and I get in trouble.',
#        'Because you go into their room without permission.',
#        "Even if I just peek in and say hey, do you wanna play? They're like ah and then you tell me to get out. And it's like it-",
#        'it only works one way.',
#        "That's what you feel? (phone ring) Whoops.", 'Yeah.',
#        'Sorry. (phone ring) My alarm.',
#        "That's supposed to be on buzzer Mom.",
#        "I know. It's just my alarm.", '(xxx)', '(phone ring)',
#        "That's why. It was my alarm.", 'But', 'sorry.',
#        'Yeah. It only works one way. It only helps a certain person instead of like everyone.',
#        'Well,', 'I feel Caleb that',
#        "you just bust into the room. You don't just peek in. I see you wander in their room when they're not even in there.",
#        "Cause I'm lookin' for something.",
#        'Cause Abby does take stuff out of my room',
#        'and just hides them.',
#        "But you need to get permission. That's the whole point is you have to get permission to go in.",
#        'I know.', '(xxx) annoying though.',
#        'So what do you think a good solution would be',
#        'instead of me just telling you what to do?', '(uhm)',
#        "I don't know.", '(hm)?', "I don't know. I'm just gonna-", "It's-",
#        "Fighting's probably not gonna stop, I mean.",
#        "It's always gonna happen.", "I can't hear you bud.", 'Okay.',
#        '(xxx)', "Don't take those off. They look loose.", 'Loose?',
#        '(sigh)', "But y- it's not all you.", 'I know.',
#        "I understand it's them too, but",
#        'you just always try to solve it on your own', 'Yeah.',
#        'with fists.',
#        'No- no- not neccessarily beating them up, but like with-',
#        'I know.', 'with',
#        'bullying I guess instead of coming and asking Mom to-',
#        "No I don't bully them.", 'to help.', 'So what-',
#        'It says we have to find a solu-', "I ask 'em first.",
#        "Then when they don't do it", 'But see bo-', 'I make them.',
#        "Do both girls say no you can't come in my room?",
#        'Not all the time.', 'Yes.',
#        'Oh, then you should be able to go in just like-',
#        "No, but I respect that one person doesn't want me to and I don't go in.",
#        'But just because', 'they-',
#        "just because that's how you run things doesn't mean that's how they run things.",
#        '(xxx)', "Well me and Allie are both gettin' older, so",
#        "opposite genders should not go into one of our rooms cause half the times they try to come in while I'm dressing for my shower.",
#        "Well yeah, they shouldn't come in during that. I totally agree with you 100%.",
#        'I know.', "They shouldn't be comin' in.",
#        'Sh- Sometimes a matter of like privacy.',
#        'I know. I wish we had a bigger house.', 'That would',
#        'solve a lot of the problems', 'because',
#        "if you guys had your own space, but we can't do that right now.",
#        "So what's a", 'different solution we could do right now?',
#        'Should we-',
#        "Tell the girls not to come in my room unless they're watching TV",
#        'or using the Xbox.', "How 'bout we ask them",
#        "to not go in your room while you're dressing?",
#        'But you gotta- we need to work out something between you and Simon.',
#        'If he wants the girls in his room, he should be able to.',
#        "But not when you're dressing, I agree. That's not okay.",
#        'You know?', "Let's see.",
#        'So what do you think roadblocks and barriers would be to that?',
#        'Me too.', 'For the-', 'you guys to stop fighting and-',
#        "and you think it's",
#        'the girls just coming in and barging in whenever they want.',
#        "I'm not picking order.", 'What?', "No I'm just kidding. (uhm)",
#        'For real though.', 'Well,',
#        "they'd probably be like oh well we don't have to do what you say. (blah blah blah)",
#        "But we're not talking about when Mom and Dad",
#        "go out and do errands. I'm talking about the every day to day stuff.",
#        '(xxx)', 'Like I might not wanna just go out.',
#        "Well, do you think it'd be good if we sat down and",
#        'talked with everyone and', 'you express your feelings about',
#        'them barging into your room and we', 'No.',
#        "make a rule that they can't just barge into your room?", 'No.',
#        "You don't think that's a good solution?",
#        "No cause they s- they'd make fun of me.", "Then what's-",
#        "Well they wouldn't know that you set up-", 'said anything.',
#        'What if we just have a family discussion',
#        'With the starting of hey, Caleb- ', 'about fighting?',
#        'We can just talk.', '(uh)', 'Start it off with fighting.',
#        'Okay.', 'Do you think that would be a good-', 'Yeah.', 'No?',
#        'Yeah.', '(hm)', '(laugh)', '(laugh)', '(uhm) Yeah.',
#        "So that's how we overcome those barriers.",
#        "(xxx) if we're goin' to bed,", 'do-',
#        'do I ever give you trouble with that?', 'Yes.',
#        "Well cause sometimes you linger and you want hugs and kisses. And I give you those and then you're like I want a hug. And I'm like I already gave you a hug. Go to bed.",
#        'But-', '(laugh)', "Well I always linger cause it's like",
#        "I'm not quite tired",
#        "but there's nothin' to do now that you sent us to bed. So I sort of just stay in that",
#        'area', "and like don't",
#        "Yeah but when- when I say it's bed time, don't you think you should",
#        'wanna actually go to bed.', 'be- you should mind?', 'Yeah, I do.',
#        'I do like get in my pajamas and stuff.', 'I just linger',
#        "cause I don't", 'quite wanna go to bed yet.',
#        'And I like hanging out with you guys more.', 'I know, but',
#        'you get a whole extra hour besides the little kids.', 'Yeah.',
#        "So do you think it's a good idea if I say go to bed, go to bed? Cause I gave you a whole extra hour. I just now started that whole new policy",
#        'what like a week ago or two weeks ago?', 'Yeah.',
#        'I thought it was about time that you guys get a- ',
#        'you and Natalie both get to', 'stay up an hour later cause',
#        "you're not a little kid. You don't need to go to bed at 7 o'clock anymore or 8 o'clock.",
#        'Yeah.', 'So', 'if I ask you to go to bed,', 'can you go to bed?',
#        'Yeah.', 'Cause like',
#        "my solution would be to put you back down to the 7 o'clock bedtime if you don't go to bed.",
#        '(cough)', "That's not very nice.", 'Yeah,',
#        "but it's not nice if you don't go to bed.", 'Yeah.',
#        "I just don't remember (xxx) go to bed.", 'Oh, I did.',
#        'You (xxx) like 50 times or something.', 'I did- not 50, only-',
#        'I only put 14 cause one for each day.', "Yeah, it's like-",
#        "But I don't know.", "I did more than 14 on one of 'em I think.",
#        'Oh no, it was just 14.', 'Oh.', 'I did 14 on my couple.',
#        'This was really', '(xxx)',
#        'How many did you put for fighting with Selix?',
#        "Fif- 14. I should've put a thousand.",
#        'And then how heated was the discussion?', 'Moderate I think.',
#        'Oh I put it as five.', 'The highest?',
#        "Yeah cause you guys get so mad when we fight. I'm not taking them off.",
#        "Don't take them off.",
#        'Well I do get angry when you guys fight bec-', 'Yeah and so-',
#        "Don't touch that.", 'Caleb,',
#        "I already- I'm gonna stop now. (xxx) Whatever.", 'quit.', 'What?',
#        "You don't like talking about this?", 'No.', "I'm fine.",
#        "I know, but that- that was really hard cause I don't even know if it's been five minutes.",
#        'I know.', 'But do you think we went through each thing?', 'Yeah.',
#        'I mean-',
#        'Do you feel like we got a good solution for fighting with kids?',
#        'Yeah.',
#        'That we have a family meeting. We start talking about some of the stuff that-',
#        'Yeah.', "that's causing the issues?", '(uhuh)',
#        'Do you think it will really work?', 'Probably.',
#        'What do you think a roadblock would be for the (xxx) siblings if we sat down and',
#        'talked? Do you think anyone would care and listen?',
#        'Or do you think that would',
#        "They'd probably all start pointing fingers at me and be like-",
#        'help?',
#        'Turn it away from what the discussion was originally started as.',
#        'Oh, I looked at that hem. I thought you took off your things.',
#        'No.',
#        'Well how can we ever- do you think we could overcome those',
#        'Yeah.', 'barriers? Cause if',
#        "they're all saying it's all Caleb's fault. Caleb.",
#        "It's not all me.",
#        "I said if the kids say it's all you, all you. How do you think would be a good way to overcome those?"],
#       dtype=object)], dtype=object)
